# %%
import pandas as pd
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
import mpt_functions as mpt
importlib.reload(mpt)
# Out:
# <module 'mpt_functions' from '/Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py'>

# %%
path = "/Users/abdullahfurkanarslan/Desktop/metropt+3+dataset 2/MetroPT3(AirCompressor).csv"
df = mpt.get_the_data_and_convert_datetime(path)
df.head()
# Out:
#    Unnamed: 0           timestamp    TP2    TP3     H1  DV_pressure  \
# 0           0 2020-02-01 00:00:00 -0.012  9.358  9.340       -0.024
# 1          10 2020-02-01 00:00:10 -0.014  9.348  9.332       -0.022
# 2          20 2020-02-01 00:00:19 -0.012  9.338  9.322       -0.022
# 3          30 2020-02-01 00:00:29 -0.012  9.328  9.312       -0.022
# 4          40 2020-02-01 00:00:39 -0.012  9.318  9.302       -0.022
#
#    Reservoirs  Oil_temperature  Motor_current  COMP  DV_eletric  Towers  MPG  \
# 0       9.358           53.600         0.0400   1.0         0.0     1.0  1.0
# 1       9.348           53.675         0.0400   1.0         0.0     1.0  1.0
# 2       9.338           53.600         0.0425   1.0         0.0     1.0  1.0
# 3       9.328           53.425         0.0400   1.0         0.0     1.0  1.0
# 4       9.318           53.475         0.0400   1.0         0.0     1.0  1.0
#
#    LPS  Pressure_switch  Oil_level  Caudal_impulses
# ...

# %% [markdown]
# "Unnamed:" 0 is not defined anywhere, dropping it should be considered

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516948 entries, 0 to 1516947
# Data columns (total 17 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Unnamed: 0       1516948 non-null  int64
#  1   timestamp        1516948 non-null  datetime64[ns]
#  2   TP2              1516948 non-null  float64
#  3   TP3              1516948 non-null  float64
#  4   H1               1516948 non-null  float64
#  5   DV_pressure      1516948 non-null  float64
#  6   Reservoirs       1516948 non-null  float64
#  7   Oil_temperature  1516948 non-null  float64
#  8   Motor_current    1516948 non-null  float64
#  9   COMP             1516948 non-null  float64
#  10  DV_eletric       1516948 non-null  float64
#  11  Towers           1516948 non-null  float64
#  12  MPG              1516948 non-null  float64
#  13  LPS              1516948 non-null  float64
#  14  Pressure_switch  1516948 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0                      timestamp           TP2  \
# count  1.516948e+06                        1516948  1.516948e+06
# mean   7.584735e+06  2020-05-16 22:58:36.631517184  1.367826e+00
# min    0.000000e+00            2020-02-01 00:00:00 -3.200000e-02
# 25%    3.792368e+06     2020-03-23 05:05:04.500000 -1.400000e-02
# 50%    7.584735e+06            2020-05-17 08:07:06 -1.200000e-02
# 75%    1.137710e+07     2020-07-10 03:07:27.500000 -1.000000e-02
# max    1.516947e+07            2020-09-01 03:59:50  1.067600e+01
# std    4.379053e+06                            NaN  3.250930e+00
#
#                 TP3            H1   DV_pressure    Reservoirs  \
# count  1.516948e+06  1.516948e+06  1.516948e+06  1.516948e+06
# mean   8.984611e+00  7.568155e+00  5.595619e-02  8.985233e+00
# min    7.300000e-01 -3.600000e-02 -3.200000e-02  7.120000e-01
# 25%    8.492000e+00  8.254000e+00 -2.200000e-02  8.494000e+00
# 50%    8.960000e+00  8.784000e+00 -2.000000e-02  8.960000e+00
# ...

# %%
df.shape
# Out:
# (1516948, 17)

# %%
df_day1 = mpt.filter_a_day("2020-02-01",df)
df_day1
# Out:
#       Unnamed: 0           timestamp    TP2    TP3     H1  DV_pressure  \
# 0              0 2020-02-01 00:00:00 -0.012  9.358  9.340       -0.024
# 1             10 2020-02-01 00:00:10 -0.014  9.348  9.332       -0.022
# 2             20 2020-02-01 00:00:19 -0.012  9.338  9.322       -0.022
# 3             30 2020-02-01 00:00:29 -0.012  9.328  9.312       -0.022
# 4             40 2020-02-01 00:00:39 -0.012  9.318  9.302       -0.022
# ...          ...                 ...    ...    ...    ...          ...
# 7139       71390 2020-02-01 23:19:41 -0.012  9.686  9.668       -0.022
# 7140       71400 2020-02-01 23:19:51 -0.010  9.678  9.660       -0.022
# 7141       71410 2020-02-01 23:20:01 -0.010  9.668  9.650       -0.022
# 7142       71420 2020-02-01 23:20:11 -0.012  9.658  9.642       -0.022
# 7143       71430 2020-02-01 23:20:21 -0.010  9.650  9.632       -0.022
#
#       Reservoirs  Oil_temperature  Motor_current  COMP  DV_eletric  Towers  \
# ...

# %%
df_day1 = mpt.aggregate_as_a_minute(df_day1)
df_day1
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:63: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
#                timestamp  Unnamed: 0       TP2       TP3        H1  \
# 0    2020-02-01 00:00:00        30.0 -0.012286  9.327429  9.311143
# 1    2020-02-01 00:01:00        95.0 -0.013000  9.260000  9.243333
# 2    2020-02-01 00:02:00       155.0 -0.012667  9.198333  9.182000
# 3    2020-02-01 00:03:00       215.0 -0.012333  9.136667  9.120667
# 4    2020-02-01 00:04:00       275.0 -0.013000  9.075667  9.060000
# ...                  ...         ...       ...       ...       ...
# 1396 2020-02-01 23:16:00     71195.0 -0.012333  9.894333  9.879333
# 1397 2020-02-01 23:17:00     71255.0 -0.010667  9.819000  9.803667
# 1398 2020-02-01 23:18:00     71315.0 -0.010333  9.757000  9.740333
# ...

# %%
mpt.plot_columns(df_day1,"timestamp", "DV_pressure")

# %%
mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day("2020-02-03", df)),"timestamp", "DV_pressure")
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:63: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()

# %%
mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day("2020-02-07", df)),"timestamp", "DV_pressure")
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:63: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()

# %% [markdown]
# mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day("2020-04-18", df)),"timestamp", "DV_pressure")

# %%
plot_columns(aggregate_as_a_minute(filter_a_day("2020-04-17", df)),"timestamp", "DV_pressure")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plot_columns(aggregate_as_a_minute(filter_a_day("2020-04-17", df)),"timestamp", "DV_pressure")
#
# NameError: name 'plot_columns' is not defined

# %%
mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day("2020-04-18", df)),"timestamp", "DV_pressure")
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()

# %%
mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day("2020-04-19", df)),"timestamp", "DV_pressure")
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()

# %%
date_list = pd.date_range(start="2020-05-29", end="2020-06-05").strftime("%Y-%m-%d").tolist()

# %%
for i in date_list:
    mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day(i, df)),"timestamp", "DV_pressure")
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# ...

# %%
for i in date_list:
    mpt.plot_columns(mpt.aggregate_as_a_minute(mpt.filter_a_day(i, df)),"timestamp", "Oil_temperature")
# Out:
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# /Users/abdullahfurkanarslan/Desktop/Graduation-Project/mpt_functions.py:58: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_minute_avg_day1 = df_day1.resample('T').mean().reset_index()
# ...

# %%
for i in date_list:
    mpt.plot_columns(mpt.aggregate_with_sliding_window_rowwise(mpt.filter_a_day(i, df), 5,3),"timestamp", "Oil_temperature")

# %%
df_day2 = mpt.filter_a_day(date_list[-1], df)
df_day2.iloc[3300:4000]
# Out:
#       Unnamed: 0           timestamp    TP2    TP3     H1  DV_pressure  \
# 3300     8904780 2020-06-05 09:05:14 -0.014  8.246  8.234       -0.022
# 3301     8904790 2020-06-05 09:05:24 -0.016  8.234  8.224       -0.022
# 3302     8904800 2020-06-05 09:05:33 -0.012  8.222  8.212       -0.020
# 3303     8904810 2020-06-05 09:05:43 -0.012  8.212  8.202       -0.020
# 3304     8904820 2020-06-05 09:05:53 -0.012  8.200  8.190       -0.020
# ...          ...                 ...    ...    ...    ...          ...
# 3995     8911730 2020-06-05 11:00:02  7.934  7.742 -0.008        2.108
# 3996     8911740 2020-06-05 11:00:12  7.948  7.764 -0.006        2.116
# 3997     8911750 2020-06-05 11:00:22  7.960  7.782 -0.006        2.120
# 3998     8911760 2020-06-05 11:00:32  7.972  7.798 -0.006        2.128
# 3999     8911770 2020-06-05 11:00:42  6.562  7.796 -0.008        1.646
#
#       Reservoirs  Oil_temperature  Motor_current  COMP  DV_eletric  Towers  \
# ...

# %%
mpt.plot_columns(df_day2.iloc[3300:6000] ,"timestamp", "Oil_temperature")

# %%
column_names = df.columns.to_list()
column_names.remove("timestamp")
column_names.remove("Unnamed: 0")

# %%
for i in column_names:
    mpt.plot_box(df, i)

# %%
for i in column_names:
    mpt.plot_columns(df, "timestamp", i)

# %%
print(column_names)
# Out:
# ['TP2', 'TP3', 'H1', 'DV_pressure', 'Reservoirs', 'Oil_temperature', 'Motor_current', 'COMP', 'DV_eletric', 'Towers', 'MPG', 'LPS', 'Pressure_switch', 'Oil_level', 'Caudal_impulses']

# %%
plt.figure(figsize=(15, 20))

for i, column in enumerate(column_names, 1):
    plt.subplot(5, 3, i)
    mpt.plot_violin(df,column)
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
column_names = df.columns.to_list()

# %%
for i in range(2,17):
    print(df[column_names[i]].value_counts())
# Out:
# TP2
# -0.012    445519
# -0.014    338189
# -0.010    245546
# -0.016    116893
# -0.008     54118
#            ...
#  3.622         1
#  2.732         1
#  3.374         1
#  1.964         1
#  2.964         1
# Name: count, Length: 5257, dtype: int64
# TP3
# 8.506    20085
# 8.168    14250
# 9.728     7444
# 8.248     6084
# 8.284     6035
#          ...
# 6.088        1
# 6.266        1
# 3.512        1
# 3.322        1
# 4.916        1
# Name: count, Length: 3683, dtype: int64
# H1
# -0.014    44232
# -0.012    41650
# -0.010    38608
# -0.008    30278
# -0.006    18208
#           ...
#  7.208        1
#  4.832        1
#  0.714        1
#  1.658        1
#  5.378        1
# Name: count, Length: 2665, dtype: int64
# DV_pressure
# -0.020    322221
# -0.022    321901
# -0.018    231808
# -0.024    228388
# -0.016    152622
#            ...
#  3.202         1
#  3.248         1
#  4.394         1
#  4.364         1
#  6.100         1
# Name: count, Length: 2257, dtype: int64
# ...
